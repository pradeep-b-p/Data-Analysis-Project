# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('./sample/img5.jpg')
image.shape
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (3072, 4080)

# %%
plt.imshow(image)

# %%
face_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_eye.xml')

# %%
plt.imshow(gray, cmap='gray')

# %%
face = face_cascade.detectMultiScale(gray)
face
# Out:
# array([[2101,  841,   40,   40],
#        [  28,  850,   64,   64],
#        [3484, 2629,   55,   55],
#        [ 689,  962,  241,  241],
#        [  65, 1057,  265,  265],
#        [3453, 2411,   79,   79],
#        [1066, 1049,  237,  237],
#        [1582,  874,  260,  260],
#        [1553,  139,   85,   85],
#        [2604, 1117,  225,  225],
#        [1576,  202,   65,   65],
#        [3826, 2584,   78,   78],
#        [3595, 2911,   55,   55],
#        [1722, 2920,   73,   73],
#        [1714, 2880,   72,   72],
#        [2928,  274,  155,  155],
#        [1153, 2837,  121,  121],
#        [1817,  953,  124,  124],
#        [2198, 1158,  222,  222],
#        [3177, 1141,  230,  230],
#        [2530, 2540,   68,   68],
#        [1659,  278,   45,   45],
#        [ 688, 2954,   59,   59],
#        [3927, 2902,   70,   70],
#        [3665, 1157,  287,  287],
#        [3489, 2585,   57,   57],
#        [2797,  340,  139,  139],
#        [ 102, 2757,   88,   88],
#        [ 247, 2884,  114,  114],
#        [2805, 2013,  200,  200],
#        [3074, 2993,   70,   70],
#        [3080, 2894,   77,   77],
#        [3054, 2927,  101,  101],
#        [1346, 2569,  105,  105],
#        [ 442, 1018,   79,   79],
#        [2445,  992,   27,   27],
#        [1528, 1090,   30,   30],
#        [ 238,  507,   59,   59],
#        [2417,  561,  106,  106],
#        [3110, 2837,   52,   52],
#        [ 340, 1212,  106,  106],
#        [ 963, 1155,   63,   63],
#        [3397, 1263,   62,   62],
#        [ 974, 1810,  444,  444],
#        [1830,  650,   56,   56],
#        [ 359, 1250,   68,   68],
#        [1593,  664,   71,   71],
#        [1675,  670,   67,   67],
#        [2246,  688,   33,   33],
#        [2338,  696,   63,   63],
#        [ 246,  697,   64,   64],
#        [2281,  719,   30,   30],
#        [ 342,  765,   43,   43],
#        [ 241,  741,   66,   66],
#        [ 246,  794,   60,   60],
#        [3184, 2224,   30,   30],
#        [3512, 1431,  557,  557],
#        [3560, 2347,   56,   56],
#        [3688, 2391,  110,  110],
#        [3931, 2259,   61,   61]], dtype=int32)

# %%
face_list = []
for (x, y, w, h) in face:
    crop = cv2.rectangle(gray, (x, y),(x+w, y+h),(0,255,0),5)
    face_list.append(crop)

# %%
for i in range(len(face_list)):
    plt.imshow(face_list[i])

# %%
plt.imshow(gray, cmap='gray')

# %%
eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)
eyes
# Out:
# array([[1642,  956,   48,   48],
#        [1734,  957,   47,   47],
#        [1616,  930,   86,   86],
#        [3563,  344,   95,   95],
#        [ 826, 1030,   47,   47],
#        [ 739, 1025,   57,   57],
#        [1202, 1107,   55,   55],
#        [1116, 1112,   53,   53],
#        [ 110, 1130,   52,   52],
#        [ 214, 1125,   60,   60],
#        [1201, 1168,   26,   26],
#        [2649, 1174,   50,   50],
#        [2735, 1186,   49,   49],
#        [3222, 1207,   45,   45],
#        [3306, 1205,   51,   51],
#        [2236, 1213,   54,   54],
#        [3732, 1236,   50,   50],
#        [2323, 1215,   54,   54],
#        [3822, 1229,   69,   69],
#        [3690, 2178,   22,   22],
#        [2515, 1435,   22,   22]], dtype=int32)

# %%
for (ex, ey, ew, eh) in eyes:
    cv2.rectangle(gray, (ex, ey),(ex+ew, ey+eh),(0,255,0),5)
plt.imshow(gray, cmap='gray')
